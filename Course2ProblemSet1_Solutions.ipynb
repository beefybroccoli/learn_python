# %% [markdown]
# # Part 1: Implement Binary Search Tree
#
# We will begin by implementing binary search tree data structure in python. Please read the descriptions of functions carefully and complete them according to description. You should be familiar with objects in python. There are many tutorials online that you can use for this : https://www.tutorialspoint.com/python/python_classes_objects.htm

# %%
class Node: 
    # Implement a node of the binary search tree.
    # Constructor for a node with key and a given parent
    # parent can be None for a root node.
    def __init__(self, key, parent = None): 
        self.key = key
        self.parent = parent 
        self.left = None # We will set left and right child to None
        self.right = None
        # Make sure that the parent's left/right pointer
        # will point to the newly created node.
        if parent != None:
            if key < parent.key:
                assert(parent.left == None), 'parent already has a left child -- unable to create node'
                parent.left = self
            else: 
                assert key > parent.key, 'key is same as parent.key. We do not allow duplicate keys in a BST since it breaks some of the algorithms.'
                assert(parent.right == None ), 'parent already has a right child -- unable to create node'
                parent.right = self
        
    # Utility function that keeps traversing left until it finds 
    # the leftmost descendant
    def get_leftmost_descendant(self):
        if self.left != None:
            return self.left.get_leftmost_descendant()
        else:
            return self
    
    # TODO: Complete the search algorithm below
    # You can call search recursively on left or right child
    # as appropriate.
    # If search succeeds: return a tuple True and the node in the tree
    # with the key we are searching for.
    # Also note that if the search fails to find the key 
    # you should return a tuple False and the node which would
    # be the parent if we were to insert the key subsequently.
    def search(self, key):
        if self.key == key: 
            # print("debug - key is ", key, ", self.key is ", self.key)
            return (True, self)
        # your code here
        #------------------------
        # if key < self, search left child
        elif key < self.key and self.left != None :
            # print("debug - look at self.left")
            return self.left.search(key)
        # if key > self, search right child
        elif key > self.key and self.right != None :
            # print("debug - look at self.right")
            return self.right.search(key)
        else:
            # print("debug - return False from search")
            return (False,self)
    
    #TODO: Complete the insert algorithm below
    # To insert first search for it and find out
    # the parent whose child the currently inserted key will be.
    # Create a new node with that key and insert.
    # return None if key already exists in the tree.
    # return the new node corresponding to the inserted key otherwise.
    def insert(self, key):
        # your code here
        # ----------------
        (boolean_key, parent_node) = self.search(key)
        # if key is found
        if boolean_key == True :
            return parent_node
        # if key is not found
        else:
            new_node = Node(key, parent_node)
            return new_node
        
    # TODO: Complete algorithm to compute height of the tree
    # height of a node whose children are both None is defined
    # to be 1.
    # height of any other node is 1 + maximum of the height 
    # of its children.
    # Return a number that is th eheight.
    def height(self):
        # your code here
        # --------------------
        if self.left == None and self.right == None:
            return 1
        elif self.left != None and self.parent == None:
            return 2 + self.left.height()
        elif self.right != None and self.parent == None:
            return 2 + self.right.height()
        elif self.left != None:
            return 1 + self.left.height()
        elif self.right != None:
            return 1 + self.right.height()

    
    #TODO: Write an algorithm to delete a key in the tree.
    # First, find the node in the tree with the key.
    # Recommend drawing pictures to visualize these cases below before
    # programming.
    # Case 1: both children of the node are None
    #   -- in this case, deletion is easy: simply find out if the node with key is its
    #      parent's left/right child and set the corr. child to None in the parent node.
    # Case 2: one of the child is None and the other is not.
    #   -- replace the node with its only child. In other words,
    #      modify the parent of the child to be the to be deleted node's parent.
    #      also change the parent's left/right child appropriately.
    # Case 3: both children of the parent are not None.
    #    -- first find its successor (go one step right and all the way to the left).
    #    -- function get_leftmost_descendant may be helpful here.
    #    -- replace the key of the node by its successor.
    #    -- delete the successor node.
    # return: no return value specified
    
    def delete(self, key):
        (found, node_to_delete) = self.search(key)
        # assert(found == True), f"key to be deleted:{key}- does not exist in the tree"
        # your code here
        # ------------------------------
        node_parent = node_to_delete.parent
        if found == True:
            # Case 1: both children of the node are None
            #   -- in this case, deletion is easy: simply find out if the node with key is its
            #      parent's left/right child and set the corr. child to None in the parent node.
            if node_to_delete.left == None and node_to_delete.right == None:
                if node_parent.left != None and node_parent.left.key == node_to_delete.key :
                    node_parent.left = None
                    print("debug - case 11, delete key ", key)
                    return (True, key)
                elif node_parent.right != None and node_parent.right.key == node_to_delete.key:
                    node_parent.right = None
                    print("debug - case 12, delete key ", key)
                    return (True, key)

            # Case 2: one of the child is None and the other is not.
            #   -- replace the node with its only child. In other words,
            #      modify the parent of the child to be the to be deleted node's parent.
            #      also change the parent's left/right child appropriately.
            elif node_to_delete.left == None and node_to_delete.right != None:
                if node_parent.left != None and node_parent.left.key == node_to_delete.key:
                    node_parent.left = node_to_delete.right
                    print("debug - case 21, delete key ", key)
                    return (True, key)
                elif node_parent.right != None and node_parent.right.key == node_to_delete.key:
                    node_parent.right = node_to_delete.right
                    print("debug - case 22, delete key ", key)
                    return (True, key)

            elif node_to_delete.left != None and node_to_delete.right == None:
                if node_parent.left != None and node_parent.left.key == node_to_delete.key:
                    node_parent.left = node_to_delete.left
                    print("debug - case 23, delete key ", key)
                    return (True, key)
                elif node_parent.right != None and node_parent.right.key == node_to_delete.key:
                    node_parent.right = node_to_delete.left
                    print("debug - case 24, delete key ", key)
                    return (True, key)

            # Case 3: both children of the parent are not None.
            #    -- first find its successor (go one step right and all the way to the left).
            #    -- function get_leftmost_descendant may be helpful here.
            #    -- replace the key of the node by its successor.
            #    -- delete the successor node.
            elif node_to_delete.left != None and node_to_delete.right != None:
                node_successor = node_to_delete.right.get_leftmost_descendant()
                node_to_delete.key = node_successor.key
                node_successor.key = key
                node_successor.delete(key)
                print("debug - case 31, delete key ", key)
                return (True, key)
        else: 
            # case 4 : return: no return value specified
            return (False, key, "not in tree")
    
    def toString(self):
        key = None
        if self.key == None:
            key = "None"
        else:
            key = self.key
        
        left = None
        if self.left == None:
            left = "None"
        else:
            left = self.left.key
        
        right = None
        if self.right == None:
            right = "None"
        else:
            right = self.right.key
        
        print("key %s, left %s, right %s" %(key, left, right) )

# %%
# # Testing deletion
# t1 = Node(16, None)
# # insert the nodes in the list
# lst = [18,25,10, 14, 8, 22, 17, 15]
# for elt in lst:
#     t1.insert(elt)

# The tree should look like this
#               16
#            /     \
#          10      18
#        /  \     /  \
#       8   14   17  25
#            \      /  
#             15    22


# for elt in lst:
#     (bool, node) = t1.search(elt)
#     if bool :
#         node.toString()

# Let us test the three deletion cases.
# case 1 let's delete node 8
# node 8 does not have left or right children.
# t1.delete(8) # should have both children nil.
# (b8,n8) = t1.search(8)
# assert not b8, 'Test A: deletion fails to delete node.'

# print("------------------")
# print("t1.delete(8) return ", t1.delete(8))
# (status,node_10) = t1.search(10)
# node_10.toString()
# print("t1.delete(8) return ", t1.delete(8))
# print("------------------")
# print("t1.delete(14) return ", t1.delete(14))
# (status,node_10) = t1.search(10)
# node_10.toString()
# print("t1.delete(14) return ", t1.delete(14))
# print("------------------")
# print("t1.delete(25) return ", t1.delete(25))
# (status,node_18) = t1.search(18)
# node_18.toString()
# print("t1.delete(25) return ", t1.delete(25))
# print("------------------")
# (status,node_16) = t1.search(16)
# node_16.toString()
# print("t1.delete(18) return ", t1.delete(18))
# (status,node_16) = t1.search(16)
# node_16.toString()
# print("t1.delete(18) return ", t1.delete(18))
# print("------------------")

# (b,n) = t1.search(10)
# assert( b) , 'Test B failed: search does not work'
# assert n.left == None, 'Test C failed: Node 8 was not properly deleted.'

# # Let us test deleting the node 14 whose right child is none.
# # n is still pointing to the node 10 after deleting 8.
# # let us ensure that it's right child is 14
# assert n.right != None, 'Test D failed: node 10 should have right child 14'
# assert n.right.key == 14, 'Test E failed: node 10 should have right child 14'

# # Let's delete node 14
# t1.delete(14)
# (b14, n14) = t1.search(14)
# assert not b14, 'Test F: Deletion of node 14 failed -- it still exists in the tree.'
# (b,n) = t1.search(10)
# assert n.right != None , 'Test G failed: deletion of node 14 not handled correctly'
# assert n.right.key == 12, f'Test H failed: deletion of node 14 not handled correctly: {n.right.key}'

# # Let's delete node 18 in the tree. 
# # It should be replaced by 22.

# t1.delete(18)
# (b18, n18) = t1.search(18)
# assert not b18, 'Test I: Deletion of node 18 failed'
# assert t1.right.key == 22 , ' Test J: Replacement of node with successor failed.'
# assert t1.right.right.left == None, ' Test K: replacement of node with successor failed -- you did not delete the successor leaf properly?'

# print('-- All tests passed: 15 points!--')

# %%
# The tree should look like this
#               16
#            /     \
#          10      18
#        /  \     /  \
#       8   14   17  25
#            \       /  
#            15    22

# %%
t1 = Node(25, None)
t2 = Node(12, t1)
t3 = Node(18, t2)
t4 = Node(40, t1)

print('-- Testing basic node construction (originally provided code) -- ')
assert(t1.left == t2), 'test 1 failed'
assert(t2.parent == t1),  'test 2 failed'
assert(t2.right == t3), 'test 3 failed'
assert (t3.parent == t2), 'test 4 failed'
assert(t1.right == t4), 'test 5 failed'
assert(t4.left == None), 'test 6 failed'
assert(t4.right == None), 'test 7 failed'
# The tree should be : 
#             25
#             /\
#         12     40
#         /\
#     None  18
#

print('-- Testing search -- ')
(b, found_node) = t1.search(18)
assert b and found_node.key == 18, 'test 8 failed'
(b, found_node) = t1.search(25)
assert b and found_node.key == 25, 'test 9 failed -- you should find the node with key 25 which is the root'
(b, found_node) = t1.search(26)
assert(not b), 'test 10 failed'
assert(found_node.key == 40), 'test 11 failed -- you should be returning the leaf node which would be the parent to the node you failed to find if it were to be inserted in the tree.'

print('-- Testing insert -- ')
ins_node = t1.insert(26)
assert ins_node.key == 26, ' test 12 failed '
assert ins_node.parent == t4,  ' test 13 failed '
assert t4.left == ins_node,  ' test 14 failed '

ins_node2 = t1.insert(33)
assert ins_node2.key == 33, 'test 15 failed'
assert ins_node2.parent == ins_node, 'test 16 failed'
assert ins_node.right == ins_node2, 'test 17 failed'

print('-- Testing height -- ')

assert t1.height() == 4, 'test 18 failed'
assert t4.height() == 3, 'test 19 failed'
assert t2.height() == 2, 'test 20 failed'

print('Success: 15 points.')
# Out:
# -- Testing basic node construction (originally provided code) --
# -- Testing search --
# -- Testing insert --
# -- Testing height --
# Success: 15 points.

# %%
# Testing deletion
t1 = Node(16, None)
# insert the nodes in the list
lst = [18,25,10, 14, 8, 22, 17, 12]
for elt in lst:
    t1.insert(elt)


# The tree should look like this
#               16
#            /     \
#          10      18
#        /  \     /  \
#       8   14   17  25
#          /         /  
#         12        22


# Let us test the three deletion cases.
# case 1 let's delete node 8
# node 8 does not have left or right children.
t1.delete(8) # should have both children nil.
(b8,n8) = t1.search(8)
assert not b8, 'Test A: deletion fails to delete node.'
(b,n) = t1.search(10)
assert( b) , 'Test B failed: search does not work'
assert n.left == None, 'Test C failed: Node 8 was not properly deleted.'

# Let us test deleting the node 14 whose right child is none.
# n is still pointing to the node 10 after deleting 8.
# let us ensure that it's right child is 14
assert n.right != None, 'Test D failed: node 10 should have right child 14'
assert n.right.key == 14, 'Test E failed: node 10 should have right child 14'

# Let's delete node 14
t1.delete(14)
(b14, n14) = t1.search(14)
assert not b14, 'Test F: Deletion of node 14 failed -- it still exists in the tree.'
(b,n) = t1.search(10)
assert n.right != None , 'Test G failed: deletion of node 14 not handled correctly'
assert n.right.key == 12, f'Test H failed: deletion of node 14 not handled correctly: {n.right.key}'

# Let's delete node 18 in the tree. 
# It should be replaced by 22.

t1.delete(18)
(b18, n18) = t1.search(18)
assert not b18, 'Test I: Deletion of node 18 failed'
assert t1.right.key == 22 , ' Test J: Replacement of node with successor failed.'
assert t1.right.right.left == None, ' Test K: replacement of node with successor failed -- you did not delete the successor leaf properly?'

print('-- All tests passed: 15 points!--')
# Out:
# debug - case 11, delete key  8
# debug - case 24, delete key  14
# debug - case 11, delete key  18
# debug - case 31, delete key  18
# -- All tests passed: 15 points!--

# %% [markdown]
# # Part 2: Height of Random Binary Search Trees
#
# The height of a binary search tree depends on the order in which we insert the keys of the tree. In this problem, we investigate a curious link between the recursion depth of quicksort algorithm on an array of n elements and the depth of binary search trees.
#
# Suppose we wish to insert keys the set of keys from $\{0, \ldots, n-1\}$ into a binary search tree. Answer the questions below.

# %% [markdown]
# ### 2(A)
# Provide examples of insertion sequences such that the resulting tree will have the worst possible  height of $n$. Note that the answer below will not be graded but you are encouraged to solve it and compare with the solutions.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### 2(B)
# Let `s1,...,sj` be a sequence of $j \geq 1$ keys inserted, wherein each `si` is a number between `0` and `n-1` and each number in the sequence is unique.
#
# Prove that if the sequence yields a tree of height `j` (worst possible case) then `s1` must be the minimum or maximum element in the sequence.
#
# **Hint:** Proof by contradiction will work. First note that `s1` will be the root of the tree obtained. Show that if `s1` is not the minimum or maximum then the resulting tree will have height < `n-1`). Note that the answer below will not be graded but you are encouraged to solve it and compare with the solutions.

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### 2(C)
# Using the implementation of the binary search tree in part 1, complete the function `calculateAverageDepth(n, numTrials)` that performs the following experiment `numTrials` number of times.
#
# Each experiment run is as follows:
#
# - Take a list of numbers from 0 to n-1.
# - Randomly shuffle the list: use random.shuffle function or (advanced) write your own shuffle.
# - Insert the randomly shuffled list into a tree.
# - Find and return the depth of the tree.
#
# Finally, we run the experiment above `numTrials` times and take the average of all the trials.
#
# We then plot the average depth of a random binary search tree as a function of n.

# %%
import random

# 1. make list of  numbers from 0 to n-1
# 2. randomly shuffle the list
# 3. insert the random list elements in order into a tree.
# 4. return the height of the resulting ree.
def run_single_experiment(n):
    # your code here
    # ---------------------
    lst = [*range(0,n-1,1)]
    random.shuffle(lst)
    t1 = Node(lst[0], None)
    for elt in lst:
        t1.insert(elt)
        # print("elt ", elt)
    return t1.height()
    
    # for elt in lst:
    #     (bool, node) = t1.search(elt)
    #     if bool :
    #         node.toString()
    
def run_multiple_trials(n, numTrials):
    lst_of_depths = [run_single_experiment(n) for j in range(numTrials)]
    return (sum(lst_of_depths)/len(lst_of_depths), lst_of_depths)

# %%
run_single_experiment(1000)
# Out:
# key 475106, left 71651, right 738936
# key 71651, left 50788, right 265885
# key 265885, left 214273, right 457241
# key 214273, left 143858, right 253287
# key 738936, left 501311, right 842271
# key 501311, left 476117, right 544053
# key 50788, left 20605, right 51769
# key 143858, left 82965, right 209948
# key 253287, left 218654, right 259708
# key 544053, left 541042, right 588477
# key 842271, left 751610, right 941251
# key 588477, left 561078, right 597748
# key 941251, left 882887, right 963977
# key 541042, left 516251, right 541158
# key 51769, left None, right 61195
# key 457241, left 393551, right 469713
# key 561078, left 555941, right 581909
# key 209948, left 203547, right 213728
# key 516251, left 509085, right 538839
# key 751610, left 742289, right 819428
# key 882887, left 858879, right 898408
# key 203547, left 153667, right 208218
# key 858879, left 852217, right 876924
# key 819428, left 792771, right 834068
# key 509085, left 508498, right 513435
# key 218654, left 217776, right 229844
# key 393551, left 347126, right 415906
# key 61195, left 51852, right 65942
# key 898408, left 888699, right 915264
# key 915264, left 904321, right 938067
# key 229844, left 221200, right 249498
# key 597748, left 594407, right 729774
# key 508498, left 506816, right 508777
# key 729774, left 724950, right 732700
# key 834068, left 831510, right 841886
# key 724950, left 656301, right 725972
# key 792771, left 775212, right 799366
# key 82965, left 74348, right 135710
# key 775212, left 768350, right 776136
# key 20605, left 6465, right 41197
# key 347126, left 327309, right 388223
# key 153667, left 143878, right 165854
# key 388223, left 367865, right 391270
# key 852217, left 849703, right 852900
# key 888699, left 885468, right 892517
# key 656301, left 649773, right 708779
# key 708779, left 707927, right 712607
# key 938067, left 926475, right 941181
# key 415906, left 405814, right 424843
# key 327309, left 297858, right 345082
# key 367865, left 353064, right 369498
# key 707927, left 678342, right 708247
# key 135710, left 117656, right 140495
# key 297858, left 284182, right 326514
# key 649773, left 613666, right 654820
# key 117656, left 103968, right 126246
# key 876924, left 873415, right 881568
# key 538839, left 536954, right 539144
# key 678342, left 668620, right 699359
# key 881568, left None, right 882061
# key 353064, left 348030, right 363446
# key 469713, left 457540, right 473408
# key 476117, left 475627, right 484472
# key 768350, left 763700, right 774729
# key 221200, left 219579, right 228798
# key 963977, left 942515, right 969556
# key 831510, left 828871, right 831697
# key 536954, left 520029, right 537156
# key 143878, left None, right 153319
# key 153319, left 149183, right 153511
# key 41197, left 32087, right 42763
# key 555941, left 551959, right 558211
# key 892517, left 890476, right 894183
# key 926475, left 917892, right 936314
# key 942515, left None, right 942552
# key 581909, left 574721, right 586595
# key 774729, left 769419, right 774876
# key 140495, left 137096, right 143209
# key 51852, left None, right 57260
# key 541158, left None, right 542791
# key 799366, left 795944, right 801600
# key 942552, left None, right 949869
# key 345082, left 344349, right 345815
# key 42763, left 41456, right 47849
# key 936314, left 926869, right 936551
# key 484472, left 482763, right 492003
# key 249498, left 245357, right 250044
# key 586595, left 583306, right 588344
# key 699359, left 692256, right 707734
# key 520029, left 519312, right 525287
# key 405814, left 401312, right 408890
# key 165854, left 162471, right 180925
# key 424843, left 424716, right 442171
# key 126246, left 119864, right 131247
# key 180925, left 179867, right 199824
# key 162471, left 156209, right 163319
# key 613666, left 607319, right 622760
# key 732700, left 731935, right 737211
# key 199824, left 191847, right 200360
# key 74348, left 73089, right 76519
# key 482763, left 476813, right 483981
# key 539144, left None, right 540726
# key 801600, left 800248, right 807631
# key 941181, left 939976, right None
# key 149183, left 146919, right 150290
# key 969556, left 967266, right 986837
# key 737211, left 735169, right None
# key 607319, left 599151, right 608121
# key 191847, left 187326, right 193289
# key 363446, left 354503, right 366576
# key 187326, left 181827, right 191178
# key 131247, left 130320, right 132667
# key 228798, left 221685, right 229308
# key 926869, left None, right 932634
# key 103968, left 95403, right 108021
# key 179867, left 177125, right None
# key 348030, left 347137, right 349165
# key 949869, left 949724, right 963854
# key 442171, left 426801, right 446240
# key 57260, left 55022, right 58603
# key 622760, left 622695, right 626075
# key 558211, left 556792, right 560033
# key 939976, left 939144, right 940435
# key 119864, left 117845, right 124246
# key 163319, left 163083, right 164607
# key 284182, left 277714, right 293635
# key 293635, left 291606, right 297734
# key 594407, left 591460, right 595380
# key 807631, left 802131, right 817962
# key 692256, left 689941, right 696991
# key 457540, left None, right 469381
# key 426801, left None, right 434673
# key 95403, left 94383, right 95809
# key 591460, left 591199, right 592871
# key 525287, left 521901, right 532177
# key 828871, left 821267, right None
# key 94383, left 93968, right None
# key 32087, left 23658, right 34767
# key 591199, left None, right None
# key 932634, left 929074, right 935606
# key 401312, left 401072, right 404731
# key 181827, left 181227, right 181875
# key 6465, left 4106, right 20261
# key 763700, left 760623, right 764378
# key 725972, left None, right 729055
# key 940435, left None, right 940492
# key 776136, left None, right 790995
# key 297734, left 297244, right None
# key 424716, left 417853, right None
# key 712607, left 709812, right 719189
# key 574721, left 566273, right 575192
# key 817962, left 813376, right None
# key 849703, left 842721, right 849773
# key 742289, left 742080, right 750545
# key 277714, left 274468, right 283040
# key 259708, left 254810, right 261824
# key 213728, left 213036, right None
# key 963854, left 963361, right None
# key 261824, left 259853, right 264905
# key 521901, left 521684, right 522866
# key 873415, left 862067, right 875135
# key 689941, left 682107, right 690622
# key 344349, left 340537, right 344643
# key 904321, left 901773, right 908051
# key 326514, left 324011, right 326595
# key 476813, left None, right 480931
# key 917892, left 916283, right 920160
# key 345815, left None, right 346767
# key 250044, left 249943, right 252720
# key 986837, left 985604, right 999843
# key 682107, left 679022, right 688043
# key 177125, left 166554, right 178109
# key 551959, left 547029, right 554298
# key 473408, left 471529, right 474885
# key 254810, left 254759, right 256714
# key 340537, left 339718, right 341806
# key 622695, left 616557, right None
# key 469381, left 459949, right None
# key 492003, left 489002, right 496970
# key 245357, left 235944, right 245989
# key 592871, left None, right 593342
# key 626075, left 623024, right 631223
# key 23658, left 23106, right 26434
# key 916283, left None, right 917297
# key 631223, left 629099, right 645948
# key 324011, left 302289, right 325972
# key 800248, left 799958, right 800449
# key 65942, left 61442, right 70586
# key 554298, left 553792, right 554779
# key 583306, left 582425, right None
# key 790995, left 779199, right 792467
# key 302289, left 302171, right 319371
# key 821267, left 820603, right 828762
# key 760623, left 753579, right 761395
# key 779199, left 779049, right 781852
# key 191178, left 188682, right None
# key 76519, left 74813, right 78929
# key 908051, left 907428, right 909571
# key 108021, left 104958, right 116103
# key 23106, left 22710, right None
# key 489002, left 485964, right 489310
# key 795944, left None, right 796523
# key 645948, left 644501, right 648258
# key 920160, left 918677, right 922026
# key 668620, left 668060, right 677374
# key 862067, left 859106, right 870862
# key 156209, left 155837, right 162155
# key 820603, left None, right None
# key 769419, left 768393, right 772851
# key 677374, left 670827, right None
# key 193289, left 192590, right 193298
# key 813376, left 812471, right 814799
# key 842721, left None, right 844799
# key 178109, left 177196, right 179098
# key 95809, left None, right 99352
# key 401072, left 394029, right 401196
# key 339718, left 332978, right 339970
# key 332978, left 328149, right 336929
# key 162155, left 160376, right None
# key 20261, left 12241, right 20421
# key 828762, left 827755, right None
# key 291606, left 285176, right 292962
# key 764378, left None, right 764552
# key 193298, left None, right 195454
# key 894183, left 893348, right 897026
# key 750545, left 747545, right 751261
# key 670827, left 669273, right 676504
# key 12241, left 10948, right 18147
# key 181875, left None, right 184616
# key 259853, left None, right 260509
# key 483981, left 483403, right None
# key 229308, left None, right 229769
# key 616557, left 614250, right 617739
# key 369498, left None, right 375809
# key 496970, left 492053, right 498672
# key 599151, left None, right 605186
# key 719189, left 717287, right 723331
# key 617739, left 617500, right 618327
# key 26434, left 26312, right 29639
# key 723331, left 720790, right None
# key 729055, left 728600, right 729157
# key 618327, left None, right 621271
# key 4106, left None, right 4998
# key 885468, left None, right 888245
# key 319371, left 311759, right 320022
# key 605186, left 601736, right None
# key 375809, left 369957, right 386255
# key 556792, left 556094, right None
# key 408890, left 406670, right 411826
# key 731935, left 730204, right None
# key 668060, left 665455, right 668401
# key 761395, left None, right 761867
# key 434673, left 433894, right 436037
# key 747545, left 742749, right 749668
# key 542791, left 541720, right None
# key 436037, left None, right 440858
# key 41456, left None, right None
# key 34767, left 32553, right 37155
# key 354503, left 353289, right 362638
# key 629099, left 627288, right 629234
# key 132667, left 132035, right 133153
# key 10948, left 8198, right None
# key 283040, left 279175, right None
# key 366576, left 365034, right 367337
# key 690622, left None, right 691889
# key 800449, left None, right None
# key 772851, left 772183, right None
# key 274468, left 273016, right 277306
# key 506816, left 506436, right 508060
# key 369957, left 369647, right 375495
# key 909571, left 908851, right 910378
# key 166554, left 166316, right 174025
# key 20421, left None, right None
# key 608121, left None, right 612774
# key 707734, left 702828, right None
# key 474885, left None, right None
# key 480931, left 478654, right None
# key 612774, left 612201, right None
# key 888245, left 887281, right 888260
# key 566273, left 561770, right 569936
# key 665455, left 657654, right 667014
# key 621271, left 618390, right None
# key 285176, left None, right 286527
# key 391270, left 389618, right 392774
# key 949724, left 948842, right None
# key 844799, left 842948, right 846316
# key 753579, left 752747, right 759500
# key 174025, left 173206, right 176763
# key 181227, left 181082, right None
# key 679022, left None, right 681633
# key 985604, left 979279, right None
# key 908851, left None, right 909375
# key 827755, left 822623, right 827834
# key 907428, left 904974, right 907486
# key 781852, left 779682, right 788140
# key 459949, left 459155, right 463632
# key 286527, left 286206, right 288605
# key 910378, left None, right 910734
# key 404731, left 401526, right 405077
# key 74813, left None, right 76514
# key 411826, left 411603, right 415393
# key 669273, left None, right None
# key 506436, left 505848, right None
# key 890476, left 889278, right 891793
# key 446240, left 445347, right 447052
# key 799958, left None, right None
# key 146919, left 145997, right 147107
# key 235944, left 235546, right 241498
# key 979279, left 972345, right 982384
# key 709812, left None, right 711564
# key 852900, left None, right 858217
# key 394029, left 393654, right 395254
# key 221685, left 221658, right 227918
# key 601736, left 599178, right 604033
# key 124246, left None, right 126241
# key 47849, left 44234, right 49479
# key 344643, left 344602, right None
# key 252720, left 250826, right None
# key 200360, left 200147, right 203376
# key 227918, left 222736, right 228512
# key 353289, left None, right 353544
# key 963361, left 950207, right None
# key 910734, left None, right 911375
# key 137096, left None, right 137852
# key 73089, left 72092, right None
# key 532177, left 530077, right 533179
# key 735169, left 733957, right 736419
# key 967266, left 966019, right 968600
# key 561770, left None, right 563156
# key 475627, left 475402, right None
# key 336929, left 334557, right None
# key 508060, left 507320, right None
# key 812471, left 808837, right None
# key 292962, left 292407, right None
# key 822623, left 821679, right 826819
# key 808837, left None, right 810017
# key 241498, left 237679, right 244753
# key 18147, left 16914, right 19712
# key 599178, left None, right 600218
# key 575192, left None, right 577823
# key 150290, left 149233, right 150826
# key 749668, left 749503, right 750432
# key 16914, left 15029, right None
# key 99352, left 98509, right 103437
# key 311759, left 309563, right 317614
# key 618390, left 618336, right None
# key 433894, left 429881, right 434143
# key 849773, left None, right None
# key 618336, left None, right None
# key 540726, left 539892, right None
# key 999843, left 994468, right 999893
# key 98509, left None, right None
# key 149233, left None, right None
# key 237679, left 236857, right 240549
# key 264905, left 264428, right 265011
# key 972345, left 970998, right 977434
# key 577823, left 575989, right None
# key 814799, left None, right 815210
# key 401196, left None, right None
# key 58603, left 57309, right 60651
# key 772183, left 770928, right None
# key 386255, left 384301, right None
# key 788140, left 785836, right 790147
# key 401526, left None, right 402687
# key 459155, left 457680, right 459812
# key 560033, left None, right None
# key 846316, left None, right 846808
# key 485964, left 484527, right 486221
# key 402687, left None, right None
# key 717287, left 713806, right 717689
# key 143209, left 141988, right 143359
# key 882061, left None, right 882270
# key 768393, left None, right 769120
# key 815210, left 815020, right 817098
# key 950207, left None, right 954851
# key 4998, left 4963, right 5339
# key 522866, left None, right None
# key 188682, left 187372, right 190418
# key 575989, left 575531, right 577025
# key 395254, left 394719, right 396226
# key 160376, left 157854, right 161160
# key 569936, left 566408, right 572634
# key 702828, left 699545, right 703054
# key 365034, left 364159, right None
# key 994468, left 989011, right 995633
# key 530077, left 526387, right 530522
# key 688043, left 687617, right 688416
# key 572634, left 570194, right 574242
# key 519312, left 518106, right None
# key 846808, left 846522, right 848071
# key 720790, left None, right None
# key 954851, left 954577, right 960869
# key 870862, left 869863, right 871908
# key 654820, left 653084, right 654959
# key 406670, left None, right None
# key 790147, left 788751, right None
# key 668401, left None, right None
# key 93968, left 87749, right None
# key 57309, left None, right 58549
# key 72092, left None, right None
# key 644501, left 642771, right None
# key 708247, left None, right 708725
# key 831697, left None, right 831718
# key 240549, left None, right None
# key 770928, left 770231, right None
# key 486221, left 486166, right 488886
# key 61442, left None, right 64149
# key 145997, left 144423, right None
# key 687617, left 685536, right None
# key 256714, left 255545, right 258659
# key 922026, left None, right 922176
# key 858217, left 854850, right None
# key 901773, left 899372, right 901947
# key 708725, left None, right None
# key 614250, left None, right None
# key 691889, left 691103, right None
# key 279175, left 279108, right 280964
# key 173206, left 169040, right 173737
# key 699545, left None, right None
# key 8198, left 7488, right 9842
# key 341806, left None, right 343487
# key 728600, left 726640, right None
# key 730204, left 730143, right 730303
# key 60651, left 60485, right None
# key 966019, left 965906, right None
# key 44234, left 42805, right 46211
# key 982384, left 979605, right 984836
# key 911375, left 910769, right 914129
# key 588344, left 587413, right None
# key 841886, left 841764, right None
# key 208218, left 204860, right None
# key 463632, left None, right 466733
# key 554779, left 554348, right 555159
# key 176763, left 175525, right None
# key 742749, left None, right 746706
# key 264428, left 262296, right None
# key 78929, left 78310, right 81297
# key 49479, left None, right 50379
# key 309563, left 308890, right 309797
# key 566408, left None, right None
# key 249943, left None, right 249951
# key 642771, left 635680, right 644405
# key 55022, left 54606, right 55235
# key 177196, left None, right None
# key 483403, left 482946, right 483746
# key 891793, left None, right None
# key 236857, left None, right None
# key 161160, left None, right None
# key 7488, left None, right 7968
# key 116103, left 113362, right None
# key 32553, left 32223, right 33944
# key 530522, left None, right 531730
# key 153511, left None, right None
# key 320022, left None, right None
# key 612201, left 609750, right None
# key 169040, left None, right 170323
# key 539892, left 539732, right 539977
# key 533179, left None, right 535654
# key 539977, left None, right None
# key 977434, left 973585, right None
# key 46211, left None, right 47469
# key 676504, left 673622, right 676779
# key 887281, left None, right 888151
# key 195454, left 194179, right None
# key 995633, left 995486, right 996452
# key 204860, left None, right 207409
# key 785836, left 782604, right 787588
# key 203376, left 200832, right None
# key 375495, left 374214, right None
# key 826819, left 824151, right None
# key 935606, left None, right None
# key 922176, left None, right 925364
# key 113362, left 112721, right None
# key 47469, left None, right None
# key 144423, left None, right None
# key 42805, left None, right 43832
# key 989011, left None, right 989189
# key 750432, left None, right None
# key 939144, left None, right None
# key 541720, left None, right None
# key 364159, left None, right 364739
# key 22710, left 21744, right None
# key 343487, left None, right 344175
# key 925364, left None, right 925597
# key 570194, left None, right None
# key 657654, left None, right 663958
# key 217776, left 216482, right None
# key 457680, left None, right 459005
# key 635680, left 632639, right 639501
# key 577025, left None, right None
# key 254759, left None, right None
# key 498672, left 497943, right 499557
# key 831718, left None, right 831999
# key 384301, left 378607, right 385237
# key 396226, left None, right 398125
# key 37155, left 35057, right 37272
# key 325972, left None, right 326171
# key 526387, left None, right None
# key 761867, left None, right None
# key 639501, left 636320, right 642637
# key 163083, left None, right None
# key 774876, left None, right 774982
# key 216482, left 215162, right 217772
# key 688416, left None, right None
# key 328149, left None, right 332934
# key 405077, left 404742, right None
# key 632639, left None, right 634738
# key 132035, left None, right None
# key 55235, left None, right None
# key 415393, left 414253, right 415824
# key 447052, left None, right 451302
# key 979605, left 979453, right 979720
# key 875135, left 875035, right 876164
# key 213036, left None, right None
# key 676779, left None, right None
# key 367337, left None, right None
# key 130320, left None, right None
# key 280964, left 280399, right None
# key 802131, left None, right 804118
# key 181082, left None, right None
# key 250826, left None, right None
# key 466733, left None, right 468703
# key 968600, left 967926, right None
# key 37272, left None, right 39325
# key 429881, left 427541, right 431921
# key 166316, left None, right None
# key 642637, left 642625, right 642689
# key 484527, left None, right 484683
# key 309797, left None, right 310833
# key 996452, left 995823, right 997294
# key 815020, left None, right None
# key 779049, left 779045, right None
# key 907486, left None, right None
# key 126241, left None, right None
# key 869863, left None, right None
# key 897026, left 896800, right 897632
# key 882270, left 882245, right None
# key 440858, left 436144, right 441860
# key 960869, left 957270, right 961158
# key 553792, left 552527, right None
# key 774982, left 774926, right None
# key 32223, left None, right None
# key 378607, left 377580, right 383666
# key 505848, left 502884, right None
# key 888151, left 887801, right None
# key 769120, left None, right None
# key 451302, left 447332, right 453414
# key 317614, left 315737, right None
# key 547029, left 545897, right 550847
# key 222736, left 221749, right 225852
# key 537156, left None, right 537699
# key 346767, left None, right None
# key 297244, left None, right 297529
# key 353544, left None, right None
# key 957270, left 955188, right 957741
# key 827834, left None, right None
# key 499557, left None, right 500588
# key 104958, left None, right 105151
# key 235546, left 233821, right None
# key 4963, left None, right None
# key 973585, left 973352, right 975404
# key 492053, left None, right 494227
# key 673622, left 673354, right 676250
# key 957741, left None, right 960538
# key 494227, left None, right 496325
# key 782604, left None, right None
# key 280399, left None, right None
# key 636320, left None, right 638489
# key 194179, left None, right 194508
# key 155837, left None, right None
# key 984836, left None, right None
# key 441860, left 441117, right None
# key 730303, left None, right 731002
# key 262296, left None, right 262340
# key 273016, left 270572, right None
# key 137852, left 137839, right 140250
# key 841764, left 838206, right None
# key 770231, left 769477, right None
# key 746706, left None, right 747408
# key 663958, left 663626, right 665339
# key 550847, left 547333, right None
# key 478654, left 477834, right 480771
# key 436144, left None, right None
# key 889278, left None, right None
# key 848071, left None, right 849344
# key 369647, left None, right None
# key 58549, left 57535, right None
# key 967926, left None, right 967950
# key 752747, left None, right None
# key 78310, left 77623, right 78473
# key 484683, left None, right 485890
# key 904974, left None, right None
# key 103437, left None, right None
# key 810017, left None, right 810656
# key 233821, left 233624, right None
# key 427541, left 426851, right 429478
# key 954577, left 954346, right None
# key 326171, left None, right None
# key 244753, left 244325, right None
# key 954346, left 950873, right None
# key 315737, left 312611, right 317557
# key 488886, left 487976, right 488941
# key 929074, left None, right None
# key 179098, left None, right 179560
# key 556094, left None, right None
# key 277306, left None, right None
# key 759500, left 757105, right 759542
# key 703054, left None, right 705617
# key 604033, left None, right None
# key 600218, left None, right 600749
# key 995486, left None, right None
# key 925597, left None, right 925617
# key 394719, left None, right None
# key 726640, left None, right None
# key 975404, left 974720, right 977034
# key 970998, left None, right None
# key 977034, left None, right None
# key 217772, left None, right None
# key 729157, left None, right 729769
# key 644405, left None, right None
# key 447332, left None, right None
# key 496325, left 494769, right None
# key 441117, left None, right None
# key 200832, left None, right 201869
# key 279108, left None, right None
# key 39325, left 37684, right None
# key 385237, left 385037, right 385964
# key 742080, left 739536, right None
# key 717689, left None, right 719156
# key 774926, left None, right None
# key 19712, left 19287, right None
# key 804118, left 803614, right 804459
# key 393654, left None, right None
# key 219579, left None, right 220477
# key 804459, left None, right 804639
# key 133153, left None, right None
# key 426851, left None, right None
# key 779045, left 778152, right None
# key 997294, left 996970, right 997990
# key 225852, left 224537, right None
# key 838206, left None, right None
# key 81297, left 78990, right None
# key 821679, left None, right None
# key 431921, left 431630, right None
# key 955188, left None, right 957133
# key 667014, left None, right None
# key 896800, left 895043, right None
# key 190418, left None, right None
# key 362638, left 359515, right None
# key 233624, left None, right None
# key 468703, left None, right None
# key 19287, left None, right None
# key 105151, left 105102, right None
# key 297529, left None, right None
# key 317557, left 317481, right None
# key 788751, left None, right 789083
# key 480771, left None, right None
# key 374214, left 373589, right None
# key 485890, left None, right None
# key 339970, left None, right None
# key 897632, left 897376, right 897708
# key 502884, left None, right 504943
# key 882245, left None, right None
# key 215162, left 214523, right None
# key 849344, left None, right None
# key 979453, left None, right None
# key 940492, left None, right None
# key 705617, left None, right None
# key 179560, left None, right 179692
# key 459005, left None, right None
# key 948842, left 942964, right None
# key 685536, left 682784, right None
# key 141988, left None, right None
# key 545897, left 544635, right 546377
# key 245989, left None, right None
# key 563156, left None, right None
# key 147107, left None, right None
# key 595380, left None, right 597103
# key 779682, left None, right None
# key 842948, left None, right None
# key 582425, left 581979, right 582538
# key 359515, left 355227, right 359809
# key 665339, left None, right None
# key 876164, left None, right None
# key 997990, left None, right None
# key 893348, left 892729, right None
# key 334557, left None, right 335545
# key 925617, left None, right None
# key 404742, left None, right None
# key 696991, left None, right 697767
# key 804639, left None, right None
# key 676250, left 675249, right None
# key 179692, left None, right None
# key 974720, left None, right None
# key 224537, left 223302, right None
# key 488941, left None, right None
# key 244325, left 242657, right None
# key 187372, left None, right 187775
# key 173737, left 173723, right None
# key 112721, left 112644, right None
# key 54606, left 53120, right None
# key 587413, left None, right None
# key 477834, left None, right None
# key 349165, left None, right 351448
# key 500588, left None, right None
# key 909375, left None, right None
# key 411603, left 410893, right None
# key 262340, left None, right 263496
# key 521684, left 521255, right None
# key 729769, left None, right None
# key 854850, left None, right None
# key 713806, left None, right None
# key 539732, left None, right None
# key 373589, left None, right None
# key 711564, left None, right 711565
# key 593342, left None, right None
# key 648258, left None, right None
# key 37684, left None, right 39268
# key 513435, left 512973, right 515841
# key 887801, left None, right 888115
# key 999893, left None, right None
# key 15029, left None, right 16749
# key 21744, left None, right None
# key 255545, left None, right 255776
# key 642625, left 640022, right None
# key 682784, left None, right None
# key 504943, left None, right None
# key 574242, left None, right 574636
# key 39268, left None, right None
# key 64149, left 63509, right None
# key 623024, left None, right None
# key 221749, left None, right None
# key 214523, left None, right None
# key 344175, left 343830, right None
# key 164607, left None, right None
# key 288605, left 286808, right None
# key 7968, left None, right None
# key 258659, left 258318, right None
# key 223302, left None, right None
# key 733957, left None, right None
# key 87749, left None, right 92870
# key 627288, left None, right None
# key 711565, left None, right None
# key 764552, left None, right None
# key 77623, left None, right None
# key 228512, left None, right None
# key 310833, left None, right None
# key 521255, left None, right None
# key 483746, left None, right None
# key 263496, left None, right None
# key 302171, left 298286, right None
# key 555159, left None, right None
# key 653084, left 650171, right None
# key 581979, left None, right None
# key 967950, left None, right None
# key 385964, left None, right None
# key 70586, left 69124, right None
# key 63509, left 61522, right None
# key 995823, left None, right None
# key 417853, left 417039, right 423756
# key 736419, left None, right None
# key 546377, left None, right None
# key 787588, left 786961, right None
# key 453414, left None, right 457185
# key 445347, left None, right None
# key 979720, left None, right 979845
# key 415824, left None, right None
# key 258318, left None, right None
# key 910769, left None, right 911337
# key 385037, left None, right None
# key 617500, left None, right None
# key 914129, left 913373, right 914934
# key 29639, left None, right 31188
# key 547333, left None, right 549495
# key 471529, left 471268, right None
# key 739536, left None, right None
# key 389618, left 389097, right 390569
# key 950873, left None, right None
# key 803614, left None, right None
# key 911337, left None, right None
# key 796523, left None, right 796931
# key 137839, left None, right None
# key 112644, left 111859, right None
# key 410893, left None, right 411380
# key 344602, left None, right None
# key 35057, left 34823, right 35421
# key 140250, left 138238, right None
# key 697767, left None, right None
# key 377580, left 377093, right None
# key 650171, left None, right None
# key 417039, left None, right None
# key 609750, left None, right None
# key 201869, left None, right None
# key 965906, left None, right None
# key 574636, left None, right None
# key 398125, left None, right 399890
# key 759542, left None, right 760343
# key 960538, left 959933, right None
# key 308890, left 308350, right None
# key 92870, left 90625, right None
# key 31188, left None, right None
# key 389097, left None, right None
# key 175525, left None, right 176141
# key 9842, left None, right None
# key 184616, left 182515, right 187224
# key 989189, left None, right None
# key 888115, left None, right None
# key 508777, left None, right None
# key 57535, left None, right 58404
# key 399890, left 399221, right None
# key 640022, left None, right 640027
# key 549495, left 548174, right 550271
# key 200147, left None, right None
# key 817098, left None, right None
# key 50379, left None, right 50765
# key 497943, left None, right None
# key 629234, left None, right None
# key 78990, left None, right None
# key 173723, left None, right None
# key 61522, left None, right 62728
# key 392774, left None, right None
# key 260509, left 260411, right None
# key 111859, left 110837, right None
# key 757105, left None, right None
# key 207409, left 205389, right None
# key 691103, left None, right None
# key 778152, left 777410, right None
# key 411380, left None, right None
# key 76514, left None, right None
# key 959933, left None, right 960435
# key 486166, left None, right None
# key 548174, left None, right None
# key 475402, left None, right None
# key 292407, left None, right None
# key 831999, left None, right None
# key 351448, left 350198, right None
# key 996970, left None, right None
# key 531730, left None, right None
# key 399221, left None, right None
# key 888260, left None, right None
# key 326595, left None, right None
# key 53120, left None, right None
# key 423756, left 422691, right 424678
# key 681633, left None, right None
# key 347137, left None, right None
# key 875035, left None, right None
# key 355227, left None, right 355982
# key 961158, left None, right None
# key 786961, left None, right None
# key 459812, left None, right None
# key 229769, left None, right None
# key 220477, left None, right None
# key 317481, left None, right None
# key 332934, left 329058, right None
# key 777410, left None, right None
# key 298286, left 297892, right 298510
# key 5339, left None, right None
# key 859106, left None, right None
# key 26312, left None, right None
# key 973352, left 973081, right None
# key 892729, left None, right 892834
# key 901947, left None, right None
# key 471268, left None, right None
# key 673354, left None, right None
# key 550271, left None, right None
# key 796931, left None, right None
# key 143359, left None, right None
# key 719156, left None, right None
# key 640027, left None, right None
# key 554348, left None, right None
# key 182515, left None, right 182898
# key 329058, left None, right 331211
# key 255776, left None, right None
# key 792467, left None, right None
# key 537699, left None, right None
# key 482946, left None, right None
# key 69124, left None, right None
# key 33944, left None, right None
# key 297892, left None, right None
# key 507320, left 507303, right None
# key 58404, left None, right None
# key 535654, left None, right None
# key 187224, left None, right None
# key 138238, left None, right None
# key 600749, left None, right None
# key 157854, left None, right 160133
# key 457185, left 456333, right None
# key 789083, left None, right None
# key 192590, left None, right None
# key 979845, left None, right 982073
# key 194508, left None, right None
# key 936551, left None, right 936959
# key 90625, left 88171, right None
# key 298510, left None, right None
# key 897376, left None, right None
# key 917297, left None, right 917561
# key 312611, left None, right 315421
# key 892834, left None, right 893176
# key 893176, left None, right None
# key 88171, left None, right None
# key 913373, left None, right None
# key 751261, left 751144, right None
# key 249951, left None, right None
# key 634738, left None, right None
# key 390569, left None, right 391246
# key 414253, left 412467, right None
# key 749503, left None, right None
# key 747408, left None, right None
# key 270572, left 270305, right None
# key 242657, left None, right None
# key 265011, left None, right None
# key 512973, left 512964, right None
# key 286808, left 286792, right None
# key 544635, left None, right None
# key 957133, left None, right None
# key 552527, left None, right None
# key 575531, left None, right None
# key 434143, left None, right None
# key 960435, left None, right None
# key 654959, left None, right None
# key 769477, left None, right None
# key 895043, left None, right None
# key 355982, left None, right 356391
# key 315421, left 313842, right None
# key 810656, left None, right 811268
# key 597103, left None, right None
# key 936959, left None, right None
# key 489310, left None, right None
# key 43832, left None, right None
# key 50765, left None, right None
# key 78473, left None, right None
# key 675249, left None, right None
# key 487976, left None, right None
# key 356391, left None, right None
# key 343830, left None, right None
# key 364739, left None, right None
# key 205389, left None, right None
# key 507303, left None, right None
# key 731002, left None, right None
# key 456333, left None, right None
# key 871908, left None, right None
# key 494769, left None, right None
# key 982073, left None, right None
# key 117845, left None, right None
# key 105102, left None, right None
# key 331211, left 330343, right None
# key 914934, left None, right None
# key 422691, left None, right None
# key 221658, left None, right None
# key 518106, left None, right None
# key 638489, left None, right None
# key 942964, left None, right None
# key 897708, left None, right None
# key 429478, left None, right None
# key 34823, left None, right None
# key 270305, left 267910, right None
# key 182898, left None, right None
# key 350198, left None, right None
# key 918677, left None, right None
# key 973081, left None, right None
# key 431630, left None, right None
# key 412467, left None, right None
# key 383666, left None, right None
# key 391246, left None, right None
# key 286206, left None, right None
# key 811268, left None, right None
# key 359809, left None, right None
# key 424678, left None, right None
# key 260411, left 260376, right None
# key 260376, left None, right None
# key 170323, left None, right None
# key 663626, left None, right None
# key 16749, left None, right None
# key 60485, left None, right None
# key 335545, left None, right None
# key 899372, left None, right None
# key 267910, left None, right None
# key 760343, left None, right None
# key 313842, left None, right None
# key 330343, left None, right None
# key 62728, left 61706, right None
# key 286792, left None, right None
# key 730143, left None, right None
# key 751144, left None, right None
# key 35421, left None, right None
# key 824151, left None, right None
# key 515841, left None, right None
# key 846522, left None, right None
# key 160133, left None, right None
# key 187775, left None, right None
# key 377093, left None, right None
# key 110837, left None, right None
# key 308350, left None, right None
# key 150826, left None, right None
# key 512964, left None, right None
# key 176141, left None, right None
# key 642689, left None, right None
# key 917561, left None, right None
# key 582538, left None, right None
# key 61706, left None, right None

# %%
from matplotlib import pyplot as plt
import math 

(avg64, lst_of_results_64) = run_multiple_trials(64,1000)
plt.hist(lst_of_results_64)
plt.xlim(0,64)
plt.xlabel('Depth of Tree')
plt.ylabel('Frequency')
plt.title('Histogram of depths for n = 64')
print(f'Average depth for 64 = {avg64}')
assert avg64 <= 12 and avg64 >= 8

plt.figure()
(avg128, lst_of_results_128) = run_multiple_trials(128,1000)
print(f'Average depth for 128 = {avg128}')
assert avg128 <= 16 and avg128 >= 12


plt.hist(lst_of_results_128)
plt.xlim(0,128)
plt.xlabel('Depth of Tree')
plt.ylabel('Frequency')
plt.title('Histogram of depths for n = 128')

nmin=16
nmax=64

lst_of_average_depths = [ run_multiple_trials(j,1000)[0] for j in range(nmin,nmax)]
plt.figure()
l1 = plt.plot(range(nmin,nmax), lst_of_average_depths,label='Avg. Depth')
plt.xlabel('n')
plt.ylabel('depth')
l2 = plt.plot(range(nmin,nmax), [1.6* math.log(j)/math.log(2) for j in range(nmin,nmax)],'--r',label='1.6log2(n)')
l3 = plt.plot(range(nmin,nmax), [2.2* math.log(j)/math.log(2) for j in range(nmin,nmax)],'--b',label='2.2log2(n)')
#plt.legend(handles=[l1, l2, l3])
plt.title('Average depth as a function of n and comparison with 1.6 log2(n), 2.2 log2(n)')
print('Passed all tests -- 15 points')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[338], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import math
#       4 (avg64, lst_of_results_64) = run_multiple_trials(64,1000)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# The histograms and plots should show an amazing fact that although the worst case depth can be as large as $n$, the depth of a random binary search tree is concentrated between $1.8\log_2(n)$ and $2.2 \log_2(n)$.
#
# This is interesting since if we can ensure that the keys are inserted at random, a BST can be quite well balanced with very high probability. There are many clever ideas on how this can be achieved in practice even if the user does not insert keys randomly. One way is called _treaps_, which we sometimes present in this class but decided to leave out for the coursera data-structures class. You can watch the treaps lecture here:
# https://youtu.be/d0rlrRZc-0s

# %% [markdown]
# ## Solutions to Manually Graded Problems

# %% [markdown]
# ### 2(A)
#
# Examples of worst case sequences include inserting in
# ascending order [0,1,...,n-1] or descending order [0,1,...,n-1].
#
#
# ### 2(B)
#
# Assuming for the sake of contradition that s1 is not the least or maximum element. However, s1 will be the root of the tree. Then there must exist a non-zero number of elements that are in the left subtree of s1 and a non-zero number of elements in the right subtree. Therefore, the maximum size of any path from root to leaf must be strictly less than j. However, the height of the tree is j. Therefore, we obtain a contradiction.
